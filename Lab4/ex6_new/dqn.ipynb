# %%
import os
import random
import time

import gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Imports all our hyperparameters from the other file
from hyperparams import Hyperparameters as params

# stable_baselines3 have wrappers that simplifies 
# the preprocessing a lot, read more about them here:
# https://stable-baselines3.readthedocs.io/en/master/common/atari_wrappers.html
from stable_baselines3.common.atari_wrappers import (
    ClipRewardEnv,
    EpisodicLifeEnv,
    FireResetEnv,
    MaxAndSkipEnv,
    NoopResetEnv,
)
from stable_baselines3.common.buffers import ReplayBuffer


# Creates our gym environment and with all our wrappers.
def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)
        if capture_video:
            if idx == 0:
                env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        env = NoopResetEnv(env, noop_max=30)
        env = MaxAndSkipEnv(env, skip=4)
        env = EpisodicLifeEnv(env)
        if "FIRE" in env.unwrapped.get_action_meanings():
            env = FireResetEnv(env)
        env = ClipRewardEnv(env)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        env = gym.wrappers.GrayScaleObservation(env)
        env = gym.wrappers.FrameStack(env, 4)
        env.seed(seed)
        env.action_space.seed(seed)
        env.observation_space.seed(seed)
        return env

    return thunk


class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        # TODO: Deinfe your network (agent)
        # Look at Section 4.1 in the paper for help: https://arxiv.org/pdf/1312.5602v1.pdf
        self.network = nn.Sequential(
            nn.Conv2d(4,16,kernel_size=8,stride=4,padding=0), #output: 16x20x20
            nn.ReLU(),
            nn.Conv2d(16,32,kernel_size=4,stride=2,padding=0), #output: 16x9x9
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(32*9*9,512),
            nn.ReLU(),
            nn.Linear(512, env.single_action_space.n)                
        )

    def forward(self, x):
        return self.network(x / 255.0)


def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

run_name = f"2{params.env_id}__{params.exp_name}__{params.seed}__{int(time.time())}"

random.seed(params.seed)
np.random.seed(params.seed)
torch.manual_seed(params.seed)
torch.backends.cudnn.deterministic = params.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# env setup
envs = gym.vector.SyncVectorEnv([make_env(params.env_id, params.seed, 0, params.capture_video, run_name)])
assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"



#q_network = QNetwork(envs).to(device)
q_network = torch.load("model2.pt").to(device)
optimizer = optim.Adam(q_network.parameters(), lr=params.learning_rate)
#target_network = QNetwork(envs).to(device)
target_network = torch.load("model2.pt").to(device)
target_network.load_state_dict(q_network.state_dict())
    
    # We’ll be using experience replay memory for training our DQN. 
    # It stores the transitions that the agent observes, allowing us to reuse this data later. 
    # By sampling from it randomly, the transitions that build up a batch are decorrelated. 
    # It has been shown that this greatly stabilizes and improves the DQN training procedure.
rb = ReplayBuffer(
    params.buffer_size,
    envs.single_observation_space,
    envs.single_action_space,
    device,
    optimize_memory_usage=False,
    handle_timeout_termination=True,
)
running_avg=[0]*100
best_running = 0
best = 0
    
obs = envs.reset()
for global_step in range(params.total_timesteps):
    # Here we get epsilon for our epislon greedy.
    epsilon = linear_schedule(params.start_e, params.end_e, params.exploration_fraction * params.total_timesteps, global_step)
        
    #print("envs shape:", obs.shape)
    if random.random() < epsilon:
        actions = envs.action_space.sample() # TODO: sample a random action from the environment 
    else:
        q_values = q_network(torch.tensor(obs).to(device))# TODO: get q_values from the network you defined, what should the network receive as input?
        actions = torch.argmax(q_values, dim=1).cpu().numpy()

        # Take a step in the environment
    next_obs, rewards, dones, infos = envs.step(actions)

        # Here we print our reward.
    for info in infos:
        if "episode" in info.keys():
            temp = info['episode']['r']
            running_avg = running_avg[1:]+[temp]
            if (temp>best):
                best=temp
            avgr = sum(running_avg)/len(running_avg)
            if (avgr>best_running):
                best_running=avgr
            print(f"global_step={global_step}, episodic_return={info['episode']['r']}, running_avg={avgr:.3f}, best_epi={best}, best_running={best_running}")
            break

        # Save data to replay buffer
    real_next_obs = next_obs.copy()
    for idx, d in enumerate(dones):
        if d:
            real_next_obs[idx] = infos[idx]["terminal_observation"]

        # Here we store the transitions in D
    rb.add(obs, real_next_obs, actions, rewards, dones, infos)

    obs = next_obs
        # Training 
    if global_step > params.learning_starts:
        if global_step % params.train_frequency == 0:
                # Sample random minibatch of transitions from D
            data = rb.sample(params.batch_size)
                # You can get data with:
                # data.observations, data.rewards, data.dones, data.actions

            with torch.no_grad():
                    # Now we calculate the y_j for non-terminal phi.
                qs=target_network(data.next_observations.to(torch.float32).to(device))
                target_max = torch.max(qs,dim=1,keepdim=True).values#.item()# TODO: Calculate max Q
                    #print(target_max)
                td_target = data.rewards + params.gamma * target_max # TODO: Calculate the td_target (y_j)
                


            old_val = q_network(data.observations.to(device)).gather(1, data.actions)
            loss = F.mse_loss(td_target, old_val) 

                # perform our gradient decent step
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # update target network
        if global_step % params.target_network_frequency == 0:
            for target_network_param, q_network_param in zip(target_network.parameters(), q_network.parameters()):
                target_network_param.data.copy_(
                    params.tau * q_network_param.data + (1.0 - params.tau) * target_network_param.data
                )

if params.save_model:
    model_path = f"runs/{run_name}/{params.exp_name}_model"
    os.mkdir(f"runs/{run_name}")
    torch.save(q_network.state_dict(), model_path)
    print(f"model saved to {model_path}")

envs.close()
# Out:
# /root/miniconda3/envs/ex6/lib/python3.9/site-packages/gym/utils/seeding.py:138: DeprecationWarning: WARN: Function `hash_seed(seed, max_bytes)` is marked as deprecated and will be removed in the future.
#   deprecation(
# /root/miniconda3/envs/ex6/lib/python3.9/site-packages/gym/utils/seeding.py:175: DeprecationWarning: WARN: Function `_bigint_from_bytes(bytes)` is marked as deprecated and will be removed in the future.
#   deprecation(
# global_step=112, episodic_return=0.0, running_avg=0.000, best_epi=0, best_running=0
# global_step=322, episodic_return=2.0, running_avg=0.020, best_epi=2.0, best_running=0.02
# global_step=433, episodic_return=0.0, running_avg=0.020, best_epi=2.0, best_running=0.02
# global_step=671, episodic_return=3.0, running_avg=0.050, best_epi=3.0, best_running=0.05
# global_step=863, episodic_return=2.0, running_avg=0.070, best_epi=3.0, best_running=0.07
# global_step=1052, episodic_return=2.0, running_avg=0.090, best_epi=3.0, best_running=0.09
# global_step=1290, episodic_return=3.0, running_avg=0.120, best_epi=3.0, best_running=0.12
# global_step=1403, episodic_return=0.0, running_avg=0.120, best_epi=3.0, best_running=0.12
# global_step=1543, episodic_return=1.0, running_avg=0.130, best_epi=3.0, best_running=0.13
# global_step=1756, episodic_return=2.0, running_avg=0.150, best_epi=3.0, best_running=0.15
# global_step=1919, episodic_return=1.0, running_avg=0.160, best_epi=3.0, best_running=0.16
# global_step=2109, episodic_return=2.0, running_avg=0.180, best_epi=3.0, best_running=0.18
# global_step=2376, episodic_return=4.0, running_avg=0.220, best_epi=4.0, best_running=0.22
# global_step=2561, episodic_return=2.0, running_avg=0.240, best_epi=4.0, best_running=0.24
# global_step=2749, episodic_return=2.0, running_avg=0.260, best_epi=4.0, best_running=0.26
# global_step=3036, episodic_return=4.0, running_avg=0.300, best_epi=4.0, best_running=0.3
# global_step=3179, episodic_return=1.0, running_avg=0.310, best_epi=4.0, best_running=0.31
# global_step=3543, episodic_return=9.0, running_avg=0.400, best_epi=9.0, best_running=0.4
# global_step=3686, episodic_return=1.0, running_avg=0.410, best_epi=9.0, best_running=0.41
# global_step=3896, episodic_return=2.0, running_avg=0.430, best_epi=9.0, best_running=0.43
# global_step=4065, episodic_return=2.0, running_avg=0.450, best_epi=9.0, best_running=0.45
# global_step=4275, episodic_return=2.0, running_avg=0.470, best_epi=9.0, best_running=0.47
# global_step=4483, episodic_return=2.0, running_avg=0.490, best_epi=9.0, best_running=0.49
# global_step=4719, episodic_return=3.0, running_avg=0.520, best_epi=9.0, best_running=0.52
# global_step=4957, episodic_return=3.0, running_avg=0.550, best_epi=9.0, best_running=0.55
# global_step=5072, episodic_return=0.0, running_avg=0.550, best_epi=9.0, best_running=0.55
# global_step=5187, episodic_return=0.0, running_avg=0.550, best_epi=9.0, best_running=0.55
# global_step=5330, episodic_return=1.0, running_avg=0.560, best_epi=9.0, best_running=0.56
# global_step=5445, episodic_return=0.0, running_avg=0.560, best_epi=9.0, best_running=0.56
# global_step=5558, episodic_return=0.0, running_avg=0.560, best_epi=9.0, best_running=0.56
# global_step=5731, episodic_return=2.0, running_avg=0.580, best_epi=9.0, best_running=0.58
# global_step=5932, episodic_return=3.0, running_avg=0.610, best_epi=9.0, best_running=0.61
# global_step=6073, episodic_return=1.0, running_avg=0.620, best_epi=9.0, best_running=0.62
# global_step=6263, episodic_return=2.0, running_avg=0.640, best_epi=9.0, best_running=0.64
# global_step=6404, episodic_return=1.0, running_avg=0.650, best_epi=9.0, best_running=0.65
# global_step=6712, episodic_return=4.0, running_avg=0.690, best_epi=9.0, best_running=0.69
# global_step=6871, episodic_return=1.0, running_avg=0.700, best_epi=9.0, best_running=0.7
# global_step=6986, episodic_return=0.0, running_avg=0.700, best_epi=9.0, best_running=0.7
# global_step=7099, episodic_return=0.0, running_avg=0.700, best_epi=9.0, best_running=0.7
# global_step=7287, episodic_return=2.0, running_avg=0.720, best_epi=9.0, best_running=0.72
# global_step=7553, episodic_return=4.0, running_avg=0.760, best_epi=9.0, best_running=0.76
# global_step=7740, episodic_return=2.0, running_avg=0.780, best_epi=9.0, best_running=0.78
# global_step=7904, episodic_return=1.0, running_avg=0.790, best_epi=9.0, best_running=0.79
# global_step=8221, episodic_return=5.0, running_avg=0.840, best_epi=9.0, best_running=0.84
# global_step=8384, episodic_return=1.0, running_avg=0.850, best_epi=9.0, best_running=0.85
# global_step=8499, episodic_return=0.0, running_avg=0.850, best_epi=9.0, best_running=0.85
# global_step=8614, episodic_return=0.0, running_avg=0.850, best_epi=9.0, best_running=0.85
# global_step=8725, episodic_return=0.0, running_avg=0.850, best_epi=9.0, best_running=0.85
# global_step=8866, episodic_return=1.0, running_avg=0.860, best_epi=9.0, best_running=0.86
# global_step=9082, episodic_return=3.0, running_avg=0.890, best_epi=9.0, best_running=0.89
# global_step=9197, episodic_return=0.0, running_avg=0.890, best_epi=9.0, best_running=0.89
# global_step=9359, episodic_return=1.0, running_avg=0.900, best_epi=9.0, best_running=0.9
# global_step=9644, episodic_return=4.0, running_avg=0.940, best_epi=9.0, best_running=0.94
# global_step=9830, episodic_return=2.0, running_avg=0.960, best_epi=9.0, best_running=0.96
# global_step=9943, episodic_return=0.0, running_avg=0.960, best_epi=9.0, best_running=0.96
# global_step=10372, episodic_return=8.0, running_avg=1.040, best_epi=9.0, best_running=1.04
# global_step=10485, episodic_return=0.0, running_avg=1.040, best_epi=9.0, best_running=1.04
# global_step=10773, episodic_return=4.0, running_avg=1.080, best_epi=9.0, best_running=1.08
# global_step=10884, episodic_return=0.0, running_avg=1.080, best_epi=9.0, best_running=1.08
# global_step=10997, episodic_return=0.0, running_avg=1.080, best_epi=9.0, best_running=1.08
# global_step=11158, episodic_return=1.0, running_avg=1.090, best_epi=9.0, best_running=1.09
# global_step=11273, episodic_return=0.0, running_avg=1.090, best_epi=9.0, best_running=1.09
# global_step=11479, episodic_return=2.0, running_avg=1.110, best_epi=9.0, best_running=1.11
# global_step=11636, episodic_return=1.0, running_avg=1.120, best_epi=9.0, best_running=1.12
# global_step=11793, episodic_return=1.0, running_avg=1.130, best_epi=9.0, best_running=1.13
# global_step=11908, episodic_return=0.0, running_avg=1.130, best_epi=9.0, best_running=1.13
# global_step=12070, episodic_return=1.0, running_avg=1.140, best_epi=9.0, best_running=1.14
# global_step=12211, episodic_return=1.0, running_avg=1.150, best_epi=9.0, best_running=1.15
# global_step=12324, episodic_return=0.0, running_avg=1.150, best_epi=9.0, best_running=1.15
# global_step=12482, episodic_return=1.0, running_avg=1.160, best_epi=9.0, best_running=1.16
# global_step=12593, episodic_return=0.0, running_avg=1.160, best_epi=9.0, best_running=1.16
# global_step=12708, episodic_return=0.0, running_avg=1.160, best_epi=9.0, best_running=1.16
# global_step=13020, episodic_return=5.0, running_avg=1.210, best_epi=9.0, best_running=1.21
# global_step=13163, episodic_return=1.0, running_avg=1.220, best_epi=9.0, best_running=1.22
# global_step=13325, episodic_return=1.0, running_avg=1.230, best_epi=9.0, best_running=1.23
# global_step=13466, episodic_return=1.0, running_avg=1.240, best_epi=9.0, best_running=1.24
# global_step=13604, episodic_return=1.0, running_avg=1.250, best_epi=9.0, best_running=1.25
# global_step=13795, episodic_return=2.0, running_avg=1.270, best_epi=9.0, best_running=1.27
# global_step=13938, episodic_return=1.0, running_avg=1.280, best_epi=9.0, best_running=1.28
# global_step=14143, episodic_return=2.0, running_avg=1.300, best_epi=9.0, best_running=1.3
# global_step=14258, episodic_return=0.0, running_avg=1.300, best_epi=9.0, best_running=1.3
# global_step=14371, episodic_return=0.0, running_avg=1.300, best_epi=9.0, best_running=1.3
# global_step=14530, episodic_return=1.0, running_avg=1.310, best_epi=9.0, best_running=1.31
# global_step=14643, episodic_return=0.0, running_avg=1.310, best_epi=9.0, best_running=1.31
# global_step=14954, episodic_return=6.0, running_avg=1.370, best_epi=9.0, best_running=1.37
# global_step=15067, episodic_return=0.0, running_avg=1.370, best_epi=9.0, best_running=1.37
# global_step=15227, episodic_return=1.0, running_avg=1.380, best_epi=9.0, best_running=1.38
# global_step=15386, episodic_return=1.0, running_avg=1.390, best_epi=9.0, best_running=1.39
# global_step=15528, episodic_return=1.0, running_avg=1.400, best_epi=9.0, best_running=1.4
# global_step=15641, episodic_return=0.0, running_avg=1.400, best_epi=9.0, best_running=1.4
# global_step=15801, episodic_return=1.0, running_avg=1.410, best_epi=9.0, best_running=1.41
# global_step=15990, episodic_return=2.0, running_avg=1.430, best_epi=9.0, best_running=1.43
# global_step=16200, episodic_return=2.0, running_avg=1.450, best_epi=9.0, best_running=1.45
# global_step=16313, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.45
# global_step=16426, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.45
# global_step=16599, episodic_return=2.0, running_avg=1.470, best_epi=9.0, best_running=1.47
# global_step=16761, episodic_return=1.0, running_avg=1.480, best_epi=9.0, best_running=1.48
# global_step=16950, episodic_return=2.0, running_avg=1.500, best_epi=9.0, best_running=1.5
# global_step=17235, episodic_return=4.0, running_avg=1.540, best_epi=9.0, best_running=1.54
# global_step=17346, episodic_return=0.0, running_avg=1.540, best_epi=9.0, best_running=1.54
# global_step=17459, episodic_return=0.0, running_avg=1.540, best_epi=9.0, best_running=1.54
# global_step=17616, episodic_return=1.0, running_avg=1.530, best_epi=9.0, best_running=1.54
# global_step=17757, episodic_return=1.0, running_avg=1.540, best_epi=9.0, best_running=1.54
# global_step=17868, episodic_return=0.0, running_avg=1.510, best_epi=9.0, best_running=1.54
# global_step=17979, episodic_return=0.0, running_avg=1.490, best_epi=9.0, best_running=1.54
# global_step=18090, episodic_return=0.0, running_avg=1.470, best_epi=9.0, best_running=1.54
# global_step=18355, episodic_return=4.0, running_avg=1.480, best_epi=9.0, best_running=1.54
# global_step=18496, episodic_return=1.0, running_avg=1.490, best_epi=9.0, best_running=1.54
# global_step=18707, episodic_return=2.0, running_avg=1.500, best_epi=9.0, best_running=1.54
# global_step=18820, episodic_return=0.0, running_avg=1.480, best_epi=9.0, best_running=1.54
# global_step=19025, episodic_return=2.0, running_avg=1.490, best_epi=9.0, best_running=1.54
# global_step=19140, episodic_return=0.0, running_avg=1.470, best_epi=9.0, best_running=1.54
# global_step=19325, episodic_return=2.0, running_avg=1.450, best_epi=9.0, best_running=1.54
# global_step=19438, episodic_return=0.0, running_avg=1.430, best_epi=9.0, best_running=1.54
# global_step=19695, episodic_return=3.0, running_avg=1.440, best_epi=9.0, best_running=1.54
# global_step=19808, episodic_return=0.0, running_avg=1.400, best_epi=9.0, best_running=1.54
# global_step=20020, episodic_return=2.0, running_avg=1.410, best_epi=9.0, best_running=1.54
# global_step=20133, episodic_return=0.0, running_avg=1.320, best_epi=9.0, best_running=1.54
# global_step=20271, episodic_return=1.0, running_avg=1.320, best_epi=9.0, best_running=1.54
# global_step=20384, episodic_return=0.0, running_avg=1.300, best_epi=9.0, best_running=1.54
# global_step=20525, episodic_return=1.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=20810, episodic_return=4.0, running_avg=1.310, best_epi=9.0, best_running=1.54
# global_step=20925, episodic_return=0.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=21233, episodic_return=4.0, running_avg=1.300, best_epi=9.0, best_running=1.54
# global_step=21371, episodic_return=1.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=21632, episodic_return=4.0, running_avg=1.320, best_epi=9.0, best_running=1.54
# global_step=21773, episodic_return=1.0, running_avg=1.330, best_epi=9.0, best_running=1.54
# global_step=21884, episodic_return=0.0, running_avg=1.320, best_epi=9.0, best_running=1.54
# global_step=21995, episodic_return=0.0, running_avg=1.320, best_epi=9.0, best_running=1.54
# global_step=22157, episodic_return=1.0, running_avg=1.330, best_epi=9.0, best_running=1.54
# global_step=22272, episodic_return=0.0, running_avg=1.310, best_epi=9.0, best_running=1.54
# global_step=22381, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=22559, episodic_return=2.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=22700, episodic_return=1.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=22811, episodic_return=0.0, running_avg=1.270, best_epi=9.0, best_running=1.54
# global_step=22997, episodic_return=2.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=23304, episodic_return=4.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=23540, episodic_return=3.0, running_avg=1.310, best_epi=9.0, best_running=1.54
# global_step=23651, episodic_return=0.0, running_avg=1.310, best_epi=9.0, best_running=1.54
# global_step=23766, episodic_return=0.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=23879, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=24065, episodic_return=2.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=24178, episodic_return=0.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=24293, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=24406, episodic_return=0.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=24521, episodic_return=0.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=24636, episodic_return=0.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=24844, episodic_return=2.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=24985, episodic_return=1.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=25096, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=25211, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=25500, episodic_return=4.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=25686, episodic_return=2.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=25845, episodic_return=1.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=26014, episodic_return=2.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=26325, episodic_return=5.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=26484, episodic_return=1.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=26697, episodic_return=2.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=26888, episodic_return=2.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=26999, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=27142, episodic_return=1.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=27257, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=27368, episodic_return=0.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=27479, episodic_return=0.0, running_avg=1.140, best_epi=9.0, best_running=1.54
# global_step=27735, episodic_return=3.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=27848, episodic_return=0.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=27963, episodic_return=0.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=28076, episodic_return=0.0, running_avg=1.140, best_epi=9.0, best_running=1.54
# global_step=28219, episodic_return=1.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=28455, episodic_return=3.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=28568, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=28679, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=28865, episodic_return=2.0, running_avg=1.140, best_epi=9.0, best_running=1.54
# global_step=29071, episodic_return=2.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=29212, episodic_return=1.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=29372, episodic_return=1.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=29531, episodic_return=1.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=29735, episodic_return=2.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=29848, episodic_return=0.0, running_avg=1.140, best_epi=9.0, best_running=1.54
# global_step=30004, episodic_return=1.0, running_avg=1.130, best_epi=9.0, best_running=1.54
# global_step=30222, episodic_return=3.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=30384, episodic_return=1.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=30499, episodic_return=0.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=30671, episodic_return=2.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=30782, episodic_return=0.0, running_avg=1.120, best_epi=9.0, best_running=1.54
# global_step=30923, episodic_return=1.0, running_avg=1.130, best_epi=9.0, best_running=1.54
# global_step=31036, episodic_return=0.0, running_avg=1.120, best_epi=9.0, best_running=1.54
# global_step=31193, episodic_return=1.0, running_avg=1.120, best_epi=9.0, best_running=1.54
# global_step=31527, episodic_return=6.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=31686, episodic_return=1.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=31975, episodic_return=4.0, running_avg=1.210, best_epi=9.0, best_running=1.54
# global_step=32213, episodic_return=3.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=32324, episodic_return=0.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=32437, episodic_return=0.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=32548, episodic_return=0.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=32663, episodic_return=0.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=32778, episodic_return=0.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=32893, episodic_return=0.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=33161, episodic_return=4.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=33300, episodic_return=1.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=33459, episodic_return=1.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=33646, episodic_return=2.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=33855, episodic_return=2.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=33968, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=34081, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=34194, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=34372, episodic_return=2.0, running_avg=1.170, best_epi=9.0, best_running=1.54
# global_step=34483, episodic_return=0.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=34644, episodic_return=1.0, running_avg=1.150, best_epi=9.0, best_running=1.54
# global_step=34800, episodic_return=1.0, running_avg=1.160, best_epi=9.0, best_running=1.54
# global_step=35064, episodic_return=4.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=35253, episodic_return=2.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=35715, episodic_return=8.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=35900, episodic_return=2.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=36122, episodic_return=3.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=36235, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=36443, episodic_return=2.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=36606, episodic_return=1.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=36766, episodic_return=1.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=36924, episodic_return=1.0, running_avg=1.300, best_epi=9.0, best_running=1.54
# global_step=37081, episodic_return=1.0, running_avg=1.300, best_epi=9.0, best_running=1.54
# global_step=37316, episodic_return=3.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=37427, episodic_return=0.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=37586, episodic_return=1.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=37699, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=37886, episodic_return=2.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=38001, episodic_return=0.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=38193, episodic_return=2.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=38352, episodic_return=1.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=38617, episodic_return=4.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=38732, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=38842, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=39051, episodic_return=2.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=39243, episodic_return=2.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=39356, episodic_return=0.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=39612, episodic_return=3.0, running_avg=1.300, best_epi=9.0, best_running=1.54
# global_step=39822, episodic_return=2.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=39933, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=40048, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=40161, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=40299, episodic_return=1.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=40414, episodic_return=0.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=40529, episodic_return=0.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=40642, episodic_return=0.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=40755, episodic_return=0.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=40947, episodic_return=2.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=41086, episodic_return=1.0, running_avg=1.270, best_epi=9.0, best_running=1.54
# global_step=41197, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=41406, episodic_return=2.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=41606, episodic_return=3.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=41721, episodic_return=0.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=41864, episodic_return=1.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=42025, episodic_return=1.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=42261, episodic_return=3.0, running_avg=1.270, best_epi=9.0, best_running=1.54
# global_step=42374, episodic_return=0.0, running_avg=1.250, best_epi=9.0, best_running=1.54
# global_step=42530, episodic_return=1.0, running_avg=1.210, best_epi=9.0, best_running=1.54
# global_step=42643, episodic_return=0.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=42833, episodic_return=2.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=42996, episodic_return=1.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=43111, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=43224, episodic_return=0.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=43335, episodic_return=0.0, running_avg=1.180, best_epi=9.0, best_running=1.54
# global_step=43494, episodic_return=1.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=43607, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=43845, episodic_return=3.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=43956, episodic_return=0.0, running_avg=1.190, best_epi=9.0, best_running=1.54
# global_step=44117, episodic_return=1.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=44277, episodic_return=1.0, running_avg=1.210, best_epi=9.0, best_running=1.54
# global_step=44464, episodic_return=2.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=44699, episodic_return=3.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=44814, episodic_return=0.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=44925, episodic_return=0.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=45115, episodic_return=2.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=45228, episodic_return=0.0, running_avg=1.200, best_epi=9.0, best_running=1.54
# global_step=45450, episodic_return=3.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=45638, episodic_return=2.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=45779, episodic_return=1.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=45966, episodic_return=2.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=46079, episodic_return=0.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=46192, episodic_return=0.0, running_avg=1.220, best_epi=9.0, best_running=1.54
# global_step=46524, episodic_return=5.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=46639, episodic_return=0.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=46752, episodic_return=0.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=46941, episodic_return=2.0, running_avg=1.230, best_epi=9.0, best_running=1.54
# global_step=47228, episodic_return=4.0, running_avg=1.270, best_epi=9.0, best_running=1.54
# global_step=47341, episodic_return=0.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=47546, episodic_return=2.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=47705, episodic_return=1.0, running_avg=1.280, best_epi=9.0, best_running=1.54
# global_step=47915, episodic_return=2.0, running_avg=1.240, best_epi=9.0, best_running=1.54
# global_step=48283, episodic_return=7.0, running_avg=1.300, best_epi=9.0, best_running=1.54
# global_step=48541, episodic_return=3.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=48656, episodic_return=0.0, running_avg=1.260, best_epi=9.0, best_running=1.54
# global_step=48889, episodic_return=3.0, running_avg=1.290, best_epi=9.0, best_running=1.54
# global_step=49176, episodic_return=4.0, running_avg=1.330, best_epi=9.0, best_running=1.54
# global_step=49291, episodic_return=0.0, running_avg=1.330, best_epi=9.0, best_running=1.54
# global_step=49450, episodic_return=1.0, running_avg=1.340, best_epi=9.0, best_running=1.54
# global_step=49637, episodic_return=2.0, running_avg=1.360, best_epi=9.0, best_running=1.54
# global_step=49891, episodic_return=3.0, running_avg=1.390, best_epi=9.0, best_running=1.54
# global_step=50034, episodic_return=1.0, running_avg=1.360, best_epi=9.0, best_running=1.54
# global_step=50433, episodic_return=7.0, running_avg=1.420, best_epi=9.0, best_running=1.54
# global_step=50619, episodic_return=2.0, running_avg=1.430, best_epi=9.0, best_running=1.54
# global_step=50953, episodic_return=5.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=51068, episodic_return=0.0, running_avg=1.440, best_epi=9.0, best_running=1.54
# global_step=51179, episodic_return=0.0, running_avg=1.440, best_epi=9.0, best_running=1.54
# global_step=51339, episodic_return=1.0, running_avg=1.450, best_epi=9.0, best_running=1.54
# global_step=51529, episodic_return=2.0, running_avg=1.470, best_epi=9.0, best_running=1.54
# global_step=51644, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.54
# global_step=51753, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.54
# global_step=51963, episodic_return=2.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=52226, episodic_return=4.0, running_avg=1.490, best_epi=9.0, best_running=1.54
# global_step=52395, episodic_return=2.0, running_avg=1.470, best_epi=9.0, best_running=1.54
# global_step=52508, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.54
# global_step=52818, episodic_return=7.0, running_avg=1.440, best_epi=9.0, best_running=1.54
# global_step=53195, episodic_return=7.0, running_avg=1.490, best_epi=9.0, best_running=1.54
# global_step=53352, episodic_return=1.0, running_avg=1.470, best_epi=9.0, best_running=1.54
# global_step=53463, episodic_return=0.0, running_avg=1.470, best_epi=9.0, best_running=1.54
# global_step=53620, episodic_return=1.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=53779, episodic_return=1.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=53894, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.54
# global_step=54080, episodic_return=2.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=54221, episodic_return=1.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=54438, episodic_return=3.0, running_avg=1.460, best_epi=9.0, best_running=1.54
# global_step=54690, episodic_return=4.0, running_avg=1.500, best_epi=9.0, best_running=1.54
# global_step=54801, episodic_return=0.0, running_avg=1.490, best_epi=9.0, best_running=1.54
# global_step=55036, episodic_return=3.0, running_avg=1.520, best_epi=9.0, best_running=1.54
# global_step=55147, episodic_return=0.0, running_avg=1.500, best_epi=9.0, best_running=1.54
# global_step=55485, episodic_return=5.0, running_avg=1.550, best_epi=9.0, best_running=1.55
# global_step=55669, episodic_return=2.0, running_avg=1.550, best_epi=9.0, best_running=1.55
# global_step=55784, episodic_return=0.0, running_avg=1.540, best_epi=9.0, best_running=1.55
# global_step=55899, episodic_return=0.0, running_avg=1.500, best_epi=9.0, best_running=1.55
# global_step=56212, episodic_return=5.0, running_avg=1.550, best_epi=9.0, best_running=1.55
# global_step=56354, episodic_return=1.0, running_avg=1.560, best_epi=9.0, best_running=1.56
# global_step=56622, episodic_return=4.0, running_avg=1.580, best_epi=9.0, best_running=1.58
# global_step=56795, episodic_return=2.0, running_avg=1.580, best_epi=9.0, best_running=1.58
# global_step=57058, episodic_return=4.0, running_avg=1.620, best_epi=9.0, best_running=1.62
# global_step=57199, episodic_return=1.0, running_avg=1.600, best_epi=9.0, best_running=1.62
# global_step=57358, episodic_return=1.0, running_avg=1.590, best_epi=9.0, best_running=1.62
# global_step=57517, episodic_return=1.0, running_avg=1.600, best_epi=9.0, best_running=1.62
# global_step=57924, episodic_return=7.0, running_avg=1.670, best_epi=9.0, best_running=1.67
# global_step=58067, episodic_return=1.0, running_avg=1.680, best_epi=9.0, best_running=1.68
# global_step=58182, episodic_return=0.0, running_avg=1.670, best_epi=9.0, best_running=1.68
# global_step=58325, episodic_return=1.0, running_avg=1.680, best_epi=9.0, best_running=1.68
# global_step=58486, episodic_return=1.0, running_avg=1.690, best_epi=9.0, best_running=1.69
# global_step=58675, episodic_return=2.0, running_avg=1.710, best_epi=9.0, best_running=1.71
# global_step=58786, episodic_return=0.0, running_avg=1.710, best_epi=9.0, best_running=1.71
# global_step=58901, episodic_return=0.0, running_avg=1.690, best_epi=9.0, best_running=1.71
# global_step=59016, episodic_return=0.0, running_avg=1.680, best_epi=9.0, best_running=1.71
# global_step=59223, episodic_return=2.0, running_avg=1.700, best_epi=9.0, best_running=1.71
# global_step=59332, episodic_return=0.0, running_avg=1.680, best_epi=9.0, best_running=1.71
# global_step=59473, episodic_return=1.0, running_avg=1.660, best_epi=9.0, best_running=1.71
# global_step=59635, episodic_return=1.0, running_avg=1.670, best_epi=9.0, best_running=1.71
# global_step=59821, episodic_return=2.0, running_avg=1.680, best_epi=9.0, best_running=1.71
# global_step=60062, episodic_return=3.0, running_avg=1.700, best_epi=9.0, best_running=1.71
# global_step=60221, episodic_return=1.0, running_avg=1.680, best_epi=9.0, best_running=1.71
# global_step=60431, episodic_return=2.0, running_avg=1.700, best_epi=9.0, best_running=1.71
# global_step=60546, episodic_return=0.0, running_avg=1.690, best_epi=9.0, best_running=1.71
# global_step=60687, episodic_return=1.0, running_avg=1.700, best_epi=9.0, best_running=1.71
# global_step=61002, episodic_return=5.0, running_avg=1.730, best_epi=9.0, best_running=1.73
# global_step=61190, episodic_return=2.0, running_avg=1.740, best_epi=9.0, best_running=1.74
# global_step=61378, episodic_return=2.0, running_avg=1.760, best_epi=9.0, best_running=1.76
# global_step=61660, episodic_return=4.0, running_avg=1.800, best_epi=9.0, best_running=1.8
# global_step=61771, episodic_return=0.0, running_avg=1.800, best_epi=9.0, best_running=1.8
# global_step=61882, episodic_return=0.0, running_avg=1.790, best_epi=9.0, best_running=1.8
# global_step=61995, episodic_return=0.0, running_avg=1.790, best_epi=9.0, best_running=1.8
# global_step=62106, episodic_return=0.0, running_avg=1.760, best_epi=9.0, best_running=1.8
# global_step=62265, episodic_return=1.0, running_avg=1.770, best_epi=9.0, best_running=1.8
# global_step=62380, episodic_return=0.0, running_avg=1.760, best_epi=9.0, best_running=1.8
# global_step=62539, episodic_return=1.0, running_avg=1.760, best_epi=9.0, best_running=1.8
# global_step=62654, episodic_return=0.0, running_avg=1.740, best_epi=9.0, best_running=1.8
# global_step=62827, episodic_return=2.0, running_avg=1.730, best_epi=9.0, best_running=1.8
# global_step=63015, episodic_return=2.0, running_avg=1.750, best_epi=9.0, best_running=1.8
# global_step=63130, episodic_return=0.0, running_avg=1.750, best_epi=9.0, best_running=1.8
# global_step=63286, episodic_return=1.0, running_avg=1.740, best_epi=9.0, best_running=1.8
# global_step=63401, episodic_return=0.0, running_avg=1.740, best_epi=9.0, best_running=1.8
# global_step=63514, episodic_return=0.0, running_avg=1.710, best_epi=9.0, best_running=1.8
# global_step=63629, episodic_return=0.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=63770, episodic_return=1.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=63931, episodic_return=1.0, running_avg=1.680, best_epi=9.0, best_running=1.8
# global_step=64072, episodic_return=1.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=64185, episodic_return=0.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=64377, episodic_return=2.0, running_avg=1.660, best_epi=9.0, best_running=1.8
# global_step=64534, episodic_return=1.0, running_avg=1.670, best_epi=9.0, best_running=1.8
# global_step=64718, episodic_return=2.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=64909, episodic_return=2.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=65119, episodic_return=2.0, running_avg=1.670, best_epi=9.0, best_running=1.8
# global_step=65278, episodic_return=1.0, running_avg=1.680, best_epi=9.0, best_running=1.8
# global_step=65533, episodic_return=3.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=65674, episodic_return=1.0, running_avg=1.690, best_epi=9.0, best_running=1.8
# global_step=65785, episodic_return=0.0, running_avg=1.670, best_epi=9.0, best_running=1.8
# global_step=65995, episodic_return=2.0, running_avg=1.620, best_epi=9.0, best_running=1.8
# global_step=66110, episodic_return=0.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=66398, episodic_return=5.0, running_avg=1.640, best_epi=9.0, best_running=1.8
# global_step=66513, episodic_return=0.0, running_avg=1.610, best_epi=9.0, best_running=1.8
# global_step=66672, episodic_return=1.0, running_avg=1.580, best_epi=9.0, best_running=1.8
# global_step=66781, episodic_return=0.0, running_avg=1.580, best_epi=9.0, best_running=1.8
# global_step=67002, episodic_return=3.0, running_avg=1.600, best_epi=9.0, best_running=1.8
# global_step=67117, episodic_return=0.0, running_avg=1.580, best_epi=9.0, best_running=1.8
# global_step=67230, episodic_return=0.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=67417, episodic_return=2.0, running_avg=1.560, best_epi=9.0, best_running=1.8
# global_step=67530, episodic_return=0.0, running_avg=1.490, best_epi=9.0, best_running=1.8
# global_step=67643, episodic_return=0.0, running_avg=1.470, best_epi=9.0, best_running=1.8
# global_step=67804, episodic_return=1.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=68174, episodic_return=9.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=68287, episodic_return=0.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=68428, episodic_return=1.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=68587, episodic_return=1.0, running_avg=1.510, best_epi=9.0, best_running=1.8
# global_step=68822, episodic_return=3.0, running_avg=1.540, best_epi=9.0, best_running=1.8
# global_step=69050, episodic_return=3.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=69165, episodic_return=0.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=69306, episodic_return=1.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=69523, episodic_return=3.0, running_avg=1.530, best_epi=9.0, best_running=1.8
# global_step=69636, episodic_return=0.0, running_avg=1.530, best_epi=9.0, best_running=1.8
# global_step=69747, episodic_return=0.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=69923, episodic_return=2.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=70038, episodic_return=0.0, running_avg=1.400, best_epi=9.0, best_running=1.8
# global_step=70153, episodic_return=0.0, running_avg=1.400, best_epi=9.0, best_running=1.8
# global_step=70294, episodic_return=1.0, running_avg=1.400, best_epi=9.0, best_running=1.8
# global_step=70435, episodic_return=1.0, running_avg=1.400, best_epi=9.0, best_running=1.8
# global_step=70721, episodic_return=4.0, running_avg=1.440, best_epi=9.0, best_running=1.8
# global_step=70976, episodic_return=3.0, running_avg=1.450, best_epi=9.0, best_running=1.8
# global_step=71165, episodic_return=2.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=71305, episodic_return=1.0, running_avg=1.440, best_epi=9.0, best_running=1.8
# global_step=71446, episodic_return=1.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=71763, episodic_return=5.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=71876, episodic_return=0.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=72181, episodic_return=4.0, running_avg=1.470, best_epi=9.0, best_running=1.8
# global_step=72322, episodic_return=1.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=72465, episodic_return=1.0, running_avg=1.420, best_epi=9.0, best_running=1.8
# global_step=72580, episodic_return=0.0, running_avg=1.420, best_epi=9.0, best_running=1.8
# global_step=72740, episodic_return=1.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=72902, episodic_return=1.0, running_avg=1.390, best_epi=9.0, best_running=1.8
# global_step=73013, episodic_return=0.0, running_avg=1.380, best_epi=9.0, best_running=1.8
# global_step=73128, episodic_return=0.0, running_avg=1.340, best_epi=9.0, best_running=1.8
# global_step=73241, episodic_return=0.0, running_avg=1.320, best_epi=9.0, best_running=1.8
# global_step=73354, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.8
# global_step=73465, episodic_return=0.0, running_avg=1.270, best_epi=9.0, best_running=1.8
# global_step=73771, episodic_return=4.0, running_avg=1.300, best_epi=9.0, best_running=1.8
# global_step=73912, episodic_return=1.0, running_avg=1.300, best_epi=9.0, best_running=1.8
# global_step=74122, episodic_return=2.0, running_avg=1.250, best_epi=9.0, best_running=1.8
# global_step=74374, episodic_return=4.0, running_avg=1.280, best_epi=9.0, best_running=1.8
# global_step=74487, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.8
# global_step=74690, episodic_return=2.0, running_avg=1.290, best_epi=9.0, best_running=1.8
# global_step=74801, episodic_return=0.0, running_avg=1.280, best_epi=9.0, best_running=1.8
# global_step=75088, episodic_return=4.0, running_avg=1.300, best_epi=9.0, best_running=1.8
# global_step=75229, episodic_return=1.0, running_avg=1.310, best_epi=9.0, best_running=1.8
# global_step=75543, episodic_return=5.0, running_avg=1.360, best_epi=9.0, best_running=1.8
# global_step=75877, episodic_return=5.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=76063, episodic_return=2.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=76250, episodic_return=2.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=76466, episodic_return=3.0, running_avg=1.450, best_epi=9.0, best_running=1.8
# global_step=76678, episodic_return=2.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=76791, episodic_return=0.0, running_avg=1.440, best_epi=9.0, best_running=1.8
# global_step=76904, episodic_return=0.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=77089, episodic_return=2.0, running_avg=1.420, best_epi=9.0, best_running=1.8
# global_step=77325, episodic_return=3.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=77583, episodic_return=3.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=77698, episodic_return=0.0, running_avg=1.450, best_epi=9.0, best_running=1.8
# global_step=77841, episodic_return=1.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=77954, episodic_return=0.0, running_avg=1.390, best_epi=9.0, best_running=1.8
# global_step=78116, episodic_return=1.0, running_avg=1.380, best_epi=9.0, best_running=1.8
# global_step=78231, episodic_return=0.0, running_avg=1.340, best_epi=9.0, best_running=1.8
# global_step=78344, episodic_return=0.0, running_avg=1.340, best_epi=9.0, best_running=1.8
# global_step=78583, episodic_return=3.0, running_avg=1.370, best_epi=9.0, best_running=1.8
# global_step=78696, episodic_return=0.0, running_avg=1.370, best_epi=9.0, best_running=1.8
# global_step=78809, episodic_return=0.0, running_avg=1.370, best_epi=9.0, best_running=1.8
# global_step=78949, episodic_return=1.0, running_avg=1.370, best_epi=9.0, best_running=1.8
# global_step=79058, episodic_return=0.0, running_avg=1.370, best_epi=9.0, best_running=1.8
# global_step=79318, episodic_return=3.0, running_avg=1.390, best_epi=9.0, best_running=1.8
# global_step=79506, episodic_return=2.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=79667, episodic_return=1.0, running_avg=1.400, best_epi=9.0, best_running=1.8
# global_step=79885, episodic_return=3.0, running_avg=1.410, best_epi=9.0, best_running=1.8
# global_step=80141, episodic_return=3.0, running_avg=1.440, best_epi=9.0, best_running=1.8
# global_step=80252, episodic_return=0.0, running_avg=1.430, best_epi=9.0, best_running=1.8
# global_step=80512, episodic_return=3.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=80627, episodic_return=0.0, running_avg=1.460, best_epi=9.0, best_running=1.8
# global_step=80787, episodic_return=1.0, running_avg=1.470, best_epi=9.0, best_running=1.8
# global_step=80975, episodic_return=2.0, running_avg=1.480, best_epi=9.0, best_running=1.8
# global_step=81309, episodic_return=5.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=81470, episodic_return=1.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=81765, episodic_return=5.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=82035, episodic_return=4.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=82176, episodic_return=1.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=82364, episodic_return=2.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=82479, episodic_return=0.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=82619, episodic_return=1.0, running_avg=1.560, best_epi=9.0, best_running=1.8
# global_step=82732, episodic_return=0.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=82966, episodic_return=3.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=83129, episodic_return=1.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=83288, episodic_return=1.0, running_avg=1.560, best_epi=9.0, best_running=1.8
# global_step=83403, episodic_return=0.0, running_avg=1.540, best_epi=9.0, best_running=1.8
# global_step=83546, episodic_return=1.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=83732, episodic_return=2.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=83972, episodic_return=3.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=84182, episodic_return=2.0, running_avg=1.560, best_epi=9.0, best_running=1.8
# global_step=84325, episodic_return=1.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=84484, episodic_return=1.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=84772, episodic_return=4.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=84958, episodic_return=2.0, running_avg=1.610, best_epi=9.0, best_running=1.8
# global_step=85071, episodic_return=0.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=85186, episodic_return=0.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=85358, episodic_return=2.0, running_avg=1.610, best_epi=9.0, best_running=1.8
# global_step=85530, episodic_return=2.0, running_avg=1.620, best_epi=9.0, best_running=1.8
# global_step=85673, episodic_return=1.0, running_avg=1.540, best_epi=9.0, best_running=1.8
# global_step=85786, episodic_return=0.0, running_avg=1.540, best_epi=9.0, best_running=1.8
# global_step=86034, episodic_return=4.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=86249, episodic_return=3.0, running_avg=1.590, best_epi=9.0, best_running=1.8
# global_step=86364, episodic_return=0.0, running_avg=1.560, best_epi=9.0, best_running=1.8
# global_step=86532, episodic_return=2.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=86645, episodic_return=0.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=86831, episodic_return=2.0, running_avg=1.560, best_epi=9.0, best_running=1.8
# global_step=87019, episodic_return=2.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=87134, episodic_return=0.0, running_avg=1.550, best_epi=9.0, best_running=1.8
# global_step=87451, episodic_return=5.0, running_avg=1.600, best_epi=9.0, best_running=1.8
# global_step=87564, episodic_return=0.0, running_avg=1.580, best_epi=9.0, best_running=1.8
# global_step=87675, episodic_return=0.0, running_avg=1.580, best_epi=9.0, best_running=1.8
# global_step=87784, episodic_return=0.0, running_avg=1.580, best_epi=9.0, best_running=1.8
# global_step=87893, episodic_return=0.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=88035, episodic_return=1.0, running_avg=1.570, best_epi=9.0, best_running=1.8
# global_step=88148, episodic_return=0.0, running_avg=1.530, best_epi=9.0, best_running=1.8
# global_step=88386, episodic_return=3.0, running_avg=1.530, best_epi=9.0, best_running=1.8
# global_step=88527, episodic_return=1.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=88688, episodic_return=1.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=88847, episodic_return=1.0, running_avg=1.520, best_epi=9.0, best_running=1.8
# global_step=89005, episodic_return=1.0, running_avg=1.480, best_epi=9.0, best_running=1.8
# global_step=89347, episodic_return=6.0, running_avg=1.540, best_epi=9.0, best_running=1.8
# ...
# global_step=3908441, episodic_return=36.0, running_avg=21.180, best_epi=374.0, best_running=26.5
# global_step=3909018, episodic_return=21.0, running_avg=21.040, best_epi=374.0, best_running=26.5
# global_step=3909681, episodic_return=14.0, running_avg=20.970, best_epi=374.0, best_running=26.5
# global_step=3910197, episodic_return=22.0, running_avg=20.970, best_epi=374.0, best_running=26.5
# global_step=3910767, episodic_return=32.0, running_avg=20.940, best_epi=374.0, best_running=26.5
# global_step=3911626, episodic_return=28.0, running_avg=20.890, best_epi=374.0, best_running=26.5
# global_step=3912345, episodic_return=155.0, running_avg=22.310, best_epi=374.0, best_running=26.5
# global_step=3912702, episodic_return=18.0, running_avg=22.370, best_epi=374.0, best_running=26.5
# global_step=3913369, episodic_return=27.0, running_avg=22.420, best_epi=374.0, best_running=26.5
# global_step=3914031, episodic_return=30.0, running_avg=22.330, best_epi=374.0, best_running=26.5
# global_step=3914561, episodic_return=15.0, running_avg=22.300, best_epi=374.0, best_running=26.5
# global_step=3915018, episodic_return=10.0, running_avg=22.170, best_epi=374.0, best_running=26.5
# global_step=3915735, episodic_return=17.0, running_avg=22.250, best_epi=374.0, best_running=26.5
# global_step=3916290, episodic_return=16.0, running_avg=21.930, best_epi=374.0, best_running=26.5
# global_step=3916858, episodic_return=20.0, running_avg=21.940, best_epi=374.0, best_running=26.5
# global_step=3917607, episodic_return=18.0, running_avg=21.960, best_epi=374.0, best_running=26.5
# global_step=3918278, episodic_return=18.0, running_avg=22.000, best_epi=374.0, best_running=26.5
# global_step=3919122, episodic_return=26.0, running_avg=22.100, best_epi=374.0, best_running=26.5
# global_step=3919596, episodic_return=17.0, running_avg=22.020, best_epi=374.0, best_running=26.5
# global_step=3920040, episodic_return=13.0, running_avg=22.080, best_epi=374.0, best_running=26.5
# global_step=3920594, episodic_return=12.0, running_avg=21.820, best_epi=374.0, best_running=26.5
# global_step=3921043, episodic_return=16.0, running_avg=21.710, best_epi=374.0, best_running=26.5
# global_step=3921790, episodic_return=28.0, running_avg=21.780, best_epi=374.0, best_running=26.5
# global_step=3922396, episodic_return=36.0, running_avg=22.000, best_epi=374.0, best_running=26.5
# global_step=3922738, episodic_return=6.0, running_avg=21.840, best_epi=374.0, best_running=26.5
# global_step=3923181, episodic_return=10.0, running_avg=21.800, best_epi=374.0, best_running=26.5
# global_step=3923584, episodic_return=8.0, running_avg=21.490, best_epi=374.0, best_running=26.5
# global_step=3924258, episodic_return=33.0, running_avg=21.660, best_epi=374.0, best_running=26.5
# global_step=3924758, episodic_return=22.0, running_avg=21.610, best_epi=374.0, best_running=26.5
# global_step=3925371, episodic_return=13.0, running_avg=21.650, best_epi=374.0, best_running=26.5
# global_step=3926202, episodic_return=23.0, running_avg=21.650, best_epi=374.0, best_running=26.5
# global_step=3926846, episodic_return=25.0, running_avg=21.620, best_epi=374.0, best_running=26.5
# global_step=3927493, episodic_return=28.0, running_avg=21.840, best_epi=374.0, best_running=26.5
# global_step=3928146, episodic_return=15.0, running_avg=21.850, best_epi=374.0, best_running=26.5
# global_step=3928621, episodic_return=14.0, running_avg=21.880, best_epi=374.0, best_running=26.5
# global_step=3929372, episodic_return=21.0, running_avg=21.840, best_epi=374.0, best_running=26.5
# global_step=3929940, episodic_return=12.0, running_avg=21.750, best_epi=374.0, best_running=26.5
# global_step=3930523, episodic_return=27.0, running_avg=21.750, best_epi=374.0, best_running=26.5
# global_step=3931257, episodic_return=29.0, running_avg=21.720, best_epi=374.0, best_running=26.5
# global_step=3931745, episodic_return=14.0, running_avg=21.700, best_epi=374.0, best_running=26.5
# global_step=3932559, episodic_return=30.0, running_avg=21.910, best_epi=374.0, best_running=26.5
# global_step=3933011, episodic_return=17.0, running_avg=21.950, best_epi=374.0, best_running=26.5
# global_step=3933874, episodic_return=31.0, running_avg=21.960, best_epi=374.0, best_running=26.5
# global_step=3934494, episodic_return=50.0, running_avg=22.270, best_epi=374.0, best_running=26.5
# global_step=3935270, episodic_return=24.0, running_avg=22.260, best_epi=374.0, best_running=26.5
# global_step=3935804, episodic_return=11.0, running_avg=22.210, best_epi=374.0, best_running=26.5
# global_step=3936296, episodic_return=14.0, running_avg=22.170, best_epi=374.0, best_running=26.5
# global_step=3937145, episodic_return=34.0, running_avg=22.330, best_epi=374.0, best_running=26.5
# global_step=3937724, episodic_return=15.0, running_avg=22.130, best_epi=374.0, best_running=26.5
# global_step=3938631, episodic_return=21.0, running_avg=22.170, best_epi=374.0, best_running=26.5
# global_step=3939291, episodic_return=18.0, running_avg=22.100, best_epi=374.0, best_running=26.5
# global_step=3939963, episodic_return=37.0, running_avg=22.260, best_epi=374.0, best_running=26.5
# global_step=3940540, episodic_return=14.0, running_avg=22.130, best_epi=374.0, best_running=26.5
# global_step=3941209, episodic_return=15.0, running_avg=21.950, best_epi=374.0, best_running=26.5
# global_step=3942156, episodic_return=38.0, running_avg=22.080, best_epi=374.0, best_running=26.5
# global_step=3942572, episodic_return=13.0, running_avg=22.010, best_epi=374.0, best_running=26.5
# global_step=3943087, episodic_return=12.0, running_avg=21.650, best_epi=374.0, best_running=26.5
# global_step=3943607, episodic_return=16.0, running_avg=21.630, best_epi=374.0, best_running=26.5
# global_step=3944196, episodic_return=17.0, running_avg=21.590, best_epi=374.0, best_running=26.5
# global_step=3944755, episodic_return=16.0, running_avg=21.470, best_epi=374.0, best_running=26.5
# global_step=3945277, episodic_return=19.0, running_avg=21.460, best_epi=374.0, best_running=26.5
# global_step=3945874, episodic_return=21.0, running_avg=21.480, best_epi=374.0, best_running=26.5
# global_step=3946392, episodic_return=16.0, running_avg=21.160, best_epi=374.0, best_running=26.5
# global_step=3946974, episodic_return=19.0, running_avg=21.060, best_epi=374.0, best_running=26.5
# global_step=3947464, episodic_return=24.0, running_avg=21.230, best_epi=374.0, best_running=26.5
# global_step=3948072, episodic_return=21.0, running_avg=21.250, best_epi=374.0, best_running=26.5
# global_step=3948830, episodic_return=19.0, running_avg=21.320, best_epi=374.0, best_running=26.5
# global_step=3949320, episodic_return=17.0, running_avg=21.390, best_epi=374.0, best_running=26.5
# global_step=3949880, episodic_return=27.0, running_avg=21.280, best_epi=374.0, best_running=26.5
# global_step=3950547, episodic_return=33.0, running_avg=21.470, best_epi=374.0, best_running=26.5
# global_step=3951236, episodic_return=17.0, running_avg=21.460, best_epi=374.0, best_running=26.5
# global_step=3951983, episodic_return=25.0, running_avg=21.510, best_epi=374.0, best_running=26.5
# global_step=3953022, episodic_return=32.0, running_avg=21.470, best_epi=374.0, best_running=26.5
# global_step=3953723, episodic_return=23.0, running_avg=21.550, best_epi=374.0, best_running=26.5
# global_step=3954565, episodic_return=32.0, running_avg=21.730, best_epi=374.0, best_running=26.5
# global_step=3955306, episodic_return=39.0, running_avg=21.990, best_epi=374.0, best_running=26.5
# global_step=3955919, episodic_return=15.0, running_avg=21.890, best_epi=374.0, best_running=26.5
# global_step=3956368, episodic_return=11.0, running_avg=21.840, best_epi=374.0, best_running=26.5
# global_step=3957081, episodic_return=19.0, running_avg=21.890, best_epi=374.0, best_running=26.5
# global_step=3957547, episodic_return=17.0, running_avg=21.800, best_epi=374.0, best_running=26.5
# global_step=3958164, episodic_return=16.0, running_avg=21.820, best_epi=374.0, best_running=26.5
# global_step=3958751, episodic_return=20.0, running_avg=21.760, best_epi=374.0, best_running=26.5
# global_step=3959206, episodic_return=8.0, running_avg=21.680, best_epi=374.0, best_running=26.5
# global_step=3959848, episodic_return=24.0, running_avg=21.700, best_epi=374.0, best_running=26.5
# global_step=3960368, episodic_return=19.0, running_avg=21.550, best_epi=374.0, best_running=26.5
# global_step=3960975, episodic_return=14.0, running_avg=21.590, best_epi=374.0, best_running=26.5
# global_step=3961500, episodic_return=11.0, running_avg=21.520, best_epi=374.0, best_running=26.5
# global_step=3962070, episodic_return=17.0, running_avg=21.550, best_epi=374.0, best_running=26.5
# global_step=3962652, episodic_return=20.0, running_avg=21.600, best_epi=374.0, best_running=26.5
# global_step=3963443, episodic_return=32.0, running_avg=21.860, best_epi=374.0, best_running=26.5
# global_step=3964096, episodic_return=23.0, running_avg=21.970, best_epi=374.0, best_running=26.5
# global_step=3964657, episodic_return=30.0, running_avg=21.990, best_epi=374.0, best_running=26.5
# global_step=3965340, episodic_return=19.0, running_avg=22.040, best_epi=374.0, best_running=26.5
# global_step=3965972, episodic_return=27.0, running_avg=22.080, best_epi=374.0, best_running=26.5
# global_step=3966503, episodic_return=12.0, running_avg=21.970, best_epi=374.0, best_running=26.5
# global_step=3967012, episodic_return=18.0, running_avg=22.080, best_epi=374.0, best_running=26.5
# global_step=3967648, episodic_return=27.0, running_avg=22.180, best_epi=374.0, best_running=26.5
# global_step=3968055, episodic_return=7.0, running_avg=22.090, best_epi=374.0, best_running=26.5
# global_step=3968704, episodic_return=19.0, running_avg=22.210, best_epi=374.0, best_running=26.5
# global_step=3969280, episodic_return=20.0, running_avg=22.170, best_epi=374.0, best_running=26.5
# global_step=3969794, episodic_return=16.0, running_avg=21.970, best_epi=374.0, best_running=26.5
# global_step=3970360, episodic_return=16.0, running_avg=21.920, best_epi=374.0, best_running=26.5
# global_step=3970944, episodic_return=21.0, running_avg=21.990, best_epi=374.0, best_running=26.5
# global_step=3971564, episodic_return=39.0, running_avg=22.160, best_epi=374.0, best_running=26.5
# global_step=3972199, episodic_return=21.0, running_avg=22.050, best_epi=374.0, best_running=26.5
# global_step=3972910, episodic_return=23.0, running_avg=22.000, best_epi=374.0, best_running=26.5
# global_step=3973544, episodic_return=21.0, running_avg=20.660, best_epi=374.0, best_running=26.5
# global_step=3974281, episodic_return=25.0, running_avg=20.730, best_epi=374.0, best_running=26.5
# global_step=3974832, episodic_return=17.0, running_avg=20.630, best_epi=374.0, best_running=26.5
# global_step=3975128, episodic_return=5.0, running_avg=20.380, best_epi=374.0, best_running=26.5
# global_step=3975741, episodic_return=18.0, running_avg=20.410, best_epi=374.0, best_running=26.5
# global_step=3976211, episodic_return=12.0, running_avg=20.430, best_epi=374.0, best_running=26.5
# global_step=3976721, episodic_return=11.0, running_avg=20.370, best_epi=374.0, best_running=26.5
# global_step=3977174, episodic_return=18.0, running_avg=20.390, best_epi=374.0, best_running=26.5
# global_step=3977777, episodic_return=16.0, running_avg=20.350, best_epi=374.0, best_running=26.5
# global_step=3978323, episodic_return=13.0, running_avg=20.300, best_epi=374.0, best_running=26.5
# global_step=3979126, episodic_return=51.0, running_avg=20.630, best_epi=374.0, best_running=26.5
# global_step=3979806, episodic_return=41.0, running_avg=20.780, best_epi=374.0, best_running=26.5
# global_step=3980222, episodic_return=27.0, running_avg=20.880, best_epi=374.0, best_running=26.5
# global_step=3980705, episodic_return=11.0, running_avg=20.860, best_epi=374.0, best_running=26.5
# global_step=3981421, episodic_return=32.0, running_avg=21.060, best_epi=374.0, best_running=26.5
# global_step=3982014, episodic_return=25.0, running_avg=21.150, best_epi=374.0, best_running=26.5
# global_step=3982367, episodic_return=7.0, running_avg=20.940, best_epi=374.0, best_running=26.5
# global_step=3982947, episodic_return=12.0, running_avg=20.700, best_epi=374.0, best_running=26.5
# global_step=3983704, episodic_return=27.0, running_avg=20.910, best_epi=374.0, best_running=26.5
# global_step=3984413, episodic_return=45.0, running_avg=21.260, best_epi=374.0, best_running=26.5
# global_step=3985086, episodic_return=28.0, running_avg=21.460, best_epi=374.0, best_running=26.5
# global_step=3985370, episodic_return=5.0, running_avg=21.180, best_epi=374.0, best_running=26.5
# global_step=3985894, episodic_return=19.0, running_avg=21.150, best_epi=374.0, best_running=26.5
# global_step=3986659, episodic_return=21.0, running_avg=21.230, best_epi=374.0, best_running=26.5
# global_step=3987103, episodic_return=10.0, running_avg=21.100, best_epi=374.0, best_running=26.5
# global_step=3987572, episodic_return=14.0, running_avg=20.990, best_epi=374.0, best_running=26.5
# global_step=3988197, episodic_return=17.0, running_avg=20.880, best_epi=374.0, best_running=26.5
# global_step=3988771, episodic_return=18.0, running_avg=20.910, best_epi=374.0, best_running=26.5
# global_step=3989590, episodic_return=43.0, running_avg=21.200, best_epi=374.0, best_running=26.5
# global_step=3989974, episodic_return=6.0, running_avg=21.050, best_epi=374.0, best_running=26.5
# global_step=3990603, episodic_return=40.0, running_avg=21.330, best_epi=374.0, best_running=26.5
# global_step=3991592, episodic_return=31.0, running_avg=21.370, best_epi=374.0, best_running=26.5
# global_step=3992252, episodic_return=23.0, running_avg=21.310, best_epi=374.0, best_running=26.5
# global_step=3993038, episodic_return=24.0, running_avg=21.410, best_epi=374.0, best_running=26.5
# global_step=3993649, episodic_return=25.0, running_avg=21.360, best_epi=374.0, best_running=26.5
# global_step=3994364, episodic_return=37.0, running_avg=21.560, best_epi=374.0, best_running=26.5
# global_step=3994795, episodic_return=15.0, running_avg=21.400, best_epi=374.0, best_running=26.5
# global_step=3995330, episodic_return=24.0, running_avg=21.140, best_epi=374.0, best_running=26.5
# global_step=3996154, episodic_return=44.0, running_avg=21.340, best_epi=374.0, best_running=26.5
# global_step=3996443, episodic_return=5.0, running_avg=21.280, best_epi=374.0, best_running=26.5
# global_step=3996817, episodic_return=7.0, running_avg=21.210, best_epi=374.0, best_running=26.5
# global_step=3997627, episodic_return=46.0, running_avg=21.330, best_epi=374.0, best_running=26.5
# global_step=3998532, episodic_return=48.0, running_avg=21.660, best_epi=374.0, best_running=26.5
# global_step=3999190, episodic_return=48.0, running_avg=21.930, best_epi=374.0, best_running=26.5
# global_step=3999697, episodic_return=11.0, running_avg=21.860, best_epi=374.0, best_running=26.5
# global_step=4000343, episodic_return=17.0, running_avg=21.660, best_epi=374.0, best_running=26.5
# global_step=4000924, episodic_return=24.0, running_avg=21.760, best_epi=374.0, best_running=26.5
# global_step=4001784, episodic_return=26.0, running_avg=21.870, best_epi=374.0, best_running=26.5
# global_step=4002350, episodic_return=32.0, running_avg=21.810, best_epi=374.0, best_running=26.5
# global_step=4002718, episodic_return=7.0, running_avg=21.750, best_epi=374.0, best_running=26.5
# global_step=4003255, episodic_return=17.0, running_avg=21.800, best_epi=374.0, best_running=26.5
# global_step=4004280, episodic_return=32.0, running_avg=21.960, best_epi=374.0, best_running=26.5
# global_step=4004810, episodic_return=27.0, running_avg=22.060, best_epi=374.0, best_running=26.5
# global_step=4005385, episodic_return=17.0, running_avg=22.070, best_epi=374.0, best_running=26.5
# global_step=4005842, episodic_return=12.0, running_avg=22.000, best_epi=374.0, best_running=26.5
# global_step=4006252, episodic_return=12.0, running_avg=21.910, best_epi=374.0, best_running=26.5
# global_step=4007122, episodic_return=32.0, running_avg=22.070, best_epi=374.0, best_running=26.5
# global_step=4007697, episodic_return=21.0, running_avg=22.090, best_epi=374.0, best_running=26.5
# global_step=4008238, episodic_return=10.0, running_avg=21.950, best_epi=374.0, best_running=26.5

# %%
torch.save(q_network,"model2.pt")
